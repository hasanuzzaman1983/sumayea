# %%
print("hi my name is sumayea")
name= input("what is your name")
#f-string
print(f"nice to meet you {name}")
# Out:
# hi my name is sumayea
# what is your namesumayea
# nice to meet you sumayea

# %%
print("Welcome to the world of codding")
print(4)
print("Hello pythno ")
print("Keywords in python are")
import keyword
print(keyword.kwlist)
# Out:
# Welcome to the world of codding
# 4
# Hello pythno
# Keywords in python are
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
